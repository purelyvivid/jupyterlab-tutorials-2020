# %% [markdown]
# # 爬蟲

# %% [markdown]
# 假設要爬這個畫面: https://www.ptt.cc/bbs/Gossiping/index39492.html

# %%
import requests
from bs4 import BeautifulSoup #匯入BeautifulSoup

s = requests.session() #取得Request Session

#通過檢查是否超過18歲的頁面
s.post('https://www.ptt.cc/ask/over18', 
          data = {'from': '/bbs/Gossiping/index.html', 'yes': 'yes'})

res = s.get('https://www.ptt.cc/bbs/Gossiping/index39492.html') #取得HTML頁面

# %%
print(res.text[:5000])
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/1284585713/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39491.html">&lsaquo; 上頁</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39493.html">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">58</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1591337774.A.1CA.html">[爆卦] 海尼根大漲價！！</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">aaron860412</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E7%88%86%E5%8D%A6%5D&#43;%E6%B5%B7%E5%B0%BC%E6%A0%B9%E5%A4%A7%E6%BC%B2%E5%83%B9%EF%BC%81%EF%BC%81">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aaaron860412">搜尋看板內 aaron860412 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 6/05</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f0">X3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1591337784.A.455.html">[新聞] 「爆料者真的可以去死！」聶永真怒批週刊</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">noname5210</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E3%80%8C%E7%88%86%E6%96%99%E8%80%85%E7%9C%9F%E7%9A%84%E5%8F%AF%E4%BB%A5%E5%8E%BB%E6%AD%BB%EF%BC%81%E3%80%8D%E8%81%B6%E6%B0%B8%E7%9C%9F%E6%80%92%E6%89%B9%E9%80%B1%E5%88%8A">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Anoname5210">搜尋看板內 noname5210 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 6/05</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1591337797.A.076.html">[問卦] 法官4怎麼知道精神病犯行當下的辨識能力?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">bengowa</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%B3%95%E5%AE%984%E6%80%8E%E9%BA%BC%E7%9F%A5%E9%81%93%E7%B2%BE%E7%A5%9E%E7%97%85%E7%8A%AF%E8%A1%8C%E7%95%B6%E4%B8%8B%E7%9A%84%E8%BE%A8%E8%AD%98%E8%83%BD%E5%8A%9B%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Abengowa">搜尋看板內 bengowa 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 6/05</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f0">XX</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1591337900.A.508.html">[新聞] 李承翰父亡　府院齊發聲明「心痛、全力</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Blayne</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>

# %% [markdown]
# 找到文章原始碼結構：

# %% [markdown]
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1591337774.A.1CA.html">[爆卦] 海尼根大漲價！！</a>
#
# 			</div>

# %%
soup = BeautifulSoup(res.text, 'html.parser') #將抓回的HTML頁面傳入BeautifulSoup，使用html.parser解析
div_tags = soup.find_all('div', {'class': 'title'}) #找到網頁中全部的 <div class="title">

for div_tag in div_tags:
    a_tag = div_tag.find('a') #找到 <div class="title"> 下的 <a>
    if a_tag is not None: #或文章被刪除會是None，所以要排除None
        print(a_tag.text) #印出文字部分
# Out:
# [爆卦] 海尼根大漲價！！
# [新聞] 「爆料者真的可以去死！」聶永真怒批週刊
# [問卦] 法官4怎麼知道精神病犯行當下的辨識能力?
# [新聞] 李承翰父亡　府院齊發聲明「心痛、全力
# [新聞] 發現馬雅文明最大建築 祭祀用長1.4公里「
# [新聞] 新北單親媽開店「整天只賣2碗湯」！網見
# Re: [爆卦] 加州地區裝甲車開出來了
# [問卦] 工讀生妹妹忘記準備道具怎麼辦?
# [問卦] 有沒有停機車不立中柱有多可惡的八卦？
# Re: [新聞] 6／6罷韓將下雨？網看戲：準備看817崩潰
# [問卦] 大概要多黑才會被認定黑人？
# [問卦] 上次在捷運暴打保全的女生呢？
# [問卦] 人類小時候是不是最廢的哺乳類嗎？
# [問卦]「時空背景不同」的話會有多少人上街抗議
# [新聞] 華航屢遭誤認陸籍航空！綠委將提案正名
# [問卦] 今天南下高鐵擠嗎？
# [問卦] 救命 我好像快要死了
# [問卦] 驚~~~大波蘿又漲價了 >.<
# [問卦] 不簽聯絡簿跟不立中柱誰比較可惡？
# [新聞] 不想看韓國瑜囂張嘴臉「我們還要被迫再
